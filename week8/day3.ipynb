# %% [markdown]
# # The Price is Right
#
# ## Week 8 Order of Play
#
# Day 1: Modal.com and SpecialistAgent
# Day 2: RAG, FrontierAgent, Ensemble Agent
# Day 3: ScannerAgent, MessengerAgent
# Day 4: AutonomousPlannerAgent and DealAgentFramework
# Day 5: The Price Is Right Finale
#
#
# Today we'll build another piece of the puzzle: a ScanningAgent that looks for promising deals by subscribing to RSS feeds.

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from agents.deals import ScrapedDeal, DealSelection
import logging
import requests
load_dotenv(override=True)
openai = OpenAI()
MODEL = 'gpt-5-mini'

# %%
deals = ScrapedDeal.fetch(show_progress=True)
# Out:
# 100%|██████████| 5/5 [02:23<00:00, 28.73s/it]

# %%
len(deals)
# Out:
# 50

# %%
deals[10].describe()
# Out:
# "Title: Hyper Tough Anti-Sag Gate Kit 2-Pack for $9 + free shipping w/ $35\nDetails: You'd pay $5 for a single kit at Walmart. Opt for store pickup (where available) to dodge the $6.99 shipping fee or orders of $35 or more ships for free. Buy Now at Walmart\nFeatures: \nURL: https://www.dealnews.com/Hyper-Tough-Anti-Sag-Gate-Kit-2-Pack-for-9-free-shipping-w-35/21743403.html?iref=rss-c196"

# %% [markdown]
# ### We are going to ask GPT-5-mini to summarize deals and identify their price

# %%
SYSTEM_PROMPT = """You identify and summarize the 5 most detailed deals from a list, by selecting deals that have the most detailed, high quality description and the most clear price.
Respond strictly in JSON with no explanation, using this format. You should provide the price as a number derived from the description. If the price of a deal isn't clear, do not include that deal in your response.
Most important is that you respond with the 5 deals that have the most detailed product description with price. It's not important to mention the terms of the deal; most important is a thorough description of the product.
Be careful with products that are described as "$XXX off" or "reduced by $XXX" - this isn't the actual price of the product. Only respond with products when you are highly confident about the price. 
"""

USER_PROMPT_PREFIX = """Respond with the most promising 5 deals from this list, selecting those which have the most detailed, high quality product description and a clear price that is greater than 0.
You should rephrase the description to be a summary of the product itself, not the terms of the deal.
Remember to respond with a short paragraph of text in the product_description field for each of the 5 items that you select.
Be careful with products that are described as "$XXX off" or "reduced by $XXX" - this isn't the actual price of the product. Only respond with products when you are highly confident about the price. 

Deals:

"""

USER_PROMPT_SUFFIX = "\n\nInclude exactly 5 deals, no more."

# %%
# this makes a suitable user prompt given scraped deals

def make_user_prompt(scraped):
    user_prompt = USER_PROMPT_PREFIX
    user_prompt += '\n\n'.join([scrape.describe() for scrape in scraped])
    user_prompt += USER_PROMPT_SUFFIX
    return user_prompt

# %%
# Let's create a user prompt for the deals we just scraped, and look at how it begins

user_prompt = make_user_prompt(deals)
print(user_prompt[:2000])
messages = [{"role": "system", "content": SYSTEM_PROMPT}, {"role": "user", "content": user_prompt}]
# Out:
# Respond with the most promising 5 deals from this list, selecting those which have the most detailed, high quality product description and a clear price.
# Respond strictly in JSON, and only JSON. You should rephrase the description to be a summary of the product itself, not the terms of the deal.
# Remember to respond with a paragraph of text in the product_description field for each of the 5 items that you select.
# Be careful with products that are described as "$XXX off" or "reduced by $XXX" - this isn't the actual price of the product. Only respond with products when you are highly confident about the price.
#
# Deals:
#
# Title: Tech Impressions Induction Wire-Free Speaker for $20 + $3.50 shipping
# Details: Just place your phone's built-in speaker on the front of the speaker, and the inductive waves created by your phone powers the speakers, no wires or Bluetooth pair required. It's half off and the best deal we could find. We've pictured it in Black, but it's also available in several other colors. Shipping and handling adds $3.50. Buy Now at HSN
# Features: contact connection technology built-in rechargeable battery measures 7"L x 5"W x 5"H
# URL: https://www.dealnews.com/Tech-Impressions-Induction-Wire-Free-Speaker-for-20-3-50-shipping/21743444.html?iref=rss-c142
#
# Title: AWOL Vision GrandVista ThunderBeat Speakers and LTV-3500 Pro+ Laser Projector Bundle for $5,999 + free shipping
# Details: That's a savings of $2,999. Buy Now at awolvision.com
# Features: all-wireless 4.2.2 surround sound system for large screen projection four other speakers two subwoofers 480W of power
# URL: https://www.dealnews.com/AWOL-Vision-Grand-Vista-Thunder-Beat-Speakers-and-LTV-3500-Pro-Laser-Projector-Bundle-for-5-999-free-shipping/21743395.html?iref=rss-c142
#
# Title: INIU 240W 3.3-Foot USB-C Cable 2-Pack for $5 + free shipping w/ $35
# Details: Clip the $5.40 coupon on the product page to snag this discount. (You must be logged in to your Walmart account to see the coupon.) Buy Now at Walmart
# Features

# %%
response = openai.chat.completions.parse(model=MODEL, messages=messages, response_format=DealSelection, reasoning_effort="minimal")
results = response.choices[0].message.parsed
results

# %%
for deal in results.deals:
    print(deal.product_description)
    print(deal.price)
    print(deal.url)
    print()

# %%
root = logging.getLogger()
root.setLevel(logging.INFO)
# Out:
# 5

# %%
from agents.scanner_agent import ScannerAgent

# %%
agent = ScannerAgent()
result = agent.scan()

# %%
result
# Out:
# DealSelection(deals=[Deal(product_description='The AWOL Vision GrandVista ThunderBeat Speakers and LTV-3500 Pro+ Laser Projector Bundle includes a set of wireless 4.2.2 surround sound system designed for large screen projection. The system features four speakers and two subwoofers, delivering a total power output of 480W. This comprehensive audio setup is designed to provide an immersive audio experience, complementing the visual quality of large-screen projections, making it suitable for home theaters and entertainment spaces.', price=5999.0, url='https://www.dealnews.com/AWOL-Vision-Grand-Vista-Thunder-Beat-Speakers-and-LTV-3500-Pro-Laser-Projector-Bundle-for-5-999-free-shipping/21743395.html?iref=rss-c142'), Deal(product_description='The Dell Inspiron Ultra 7 155H is a 16-inch 2-in-1 touch laptop designed for versatility and performance. It features an Intel Core Ultra 7 155H processor with 1.4GHz clock speed and 16 cores, along with 16GB of RAM and a fast 1TB SSD for storage. The laptop sports a 16-inch 2560x1600 (2.5K) IPS touch display, providing sharp visuals and responsive touch input. It comes with Windows 11 Home pre-installed, offering a modern and user-friendly operating system.', price=900.0, url='https://www.dealnews.com/Dell-Inspiron-Ultra-7-155-H-16-2-in-1-Touch-Laptop-w-1-TB-SSD-for-900-free-shipping/21743410.html?iref=rss-c39'), Deal(product_description='The Dreame X50 Ultra Robot Vacuum and Mop is a certified refurbished all-in-one cleaning solution for your home.  The robot features smart obstacle avoidance, and Vormax suction to effectively clean floors. It includes a SideReach vacuuming feature, auto maintenance capabilities, MopExtend technology, and AceClean dryboard to ensure your floors are sparkling clean and dry.  The Dreame X50 Ultra can automatically empty its dustbin and is designed to provide a comprehensive cleaning experience for various floor types.', price=940.0, url='https://www.dealnews.com/Certified-Refurb-Dreame-X50-Ultra-20-000-Pa-Auto-Empty-Robot-Vacuum-and-Mop-for-940-free-shipping/21743440.html?iref=rss-f1912'), Deal(product_description="The Pawsync Smart Pet Feeder is an integrated device designed to automate and monitor pet feeding. It comes equipped with a built-in smart feeder scale for precise portioning, smart jam fix technology to prevent food blockages, and automatic meal tracking to keep records of your pet's feeding habits. The feeder also includes a feeding calculator to determine the appropriate amount of food based on your pet's needs, providing a comprehensive solution for pet owners looking to manage their pet's diet efficiently.", price=80.0, url='https://www.dealnews.com/products/Pawsync/Pawsync-Smart-Pet-Feeder/489200.html?iref=rss-f1912'), Deal(product_description='The Samsung 7.5-Cubic Foot Smart Electric Dryer is designed with multiple features for efficient and convenient laundry care.  It offers Steam Sanitize+ to eliminate bacteria, flexible installation options for stacked or side-by-side setup, and smart dryer Wi-Fi connectivity for remote control and monitoring. The dryer also uses Sensor Dry technology with a moisture sensor to optimize drying time and prevent over-drying, ensuring clothes are cared for properly. The model number is DVE50BG8300VA3.', price=849.0, url='https://www.dealnews.com/products/Samsung/7-5-Cubic-Foot-Smart-Electric-Dryer-with-Steam-Sanitize-and-Sensor-Dry/490227.html?iref=rss-f1912')])

# %% [markdown]
# ### Introducing Pushover
#
# Pushover is a nifty tool for sending Push Notifications to your phone.
#
# It's super easy to set up and install!
#
# Simply visit https://pushover.net/ and click 'Login or Signup' on the top right to sign up for a free account, and create your API keys.
#
# Once you've signed up, on the home screen, click "Create an Application/API Token", and give it any name (like AIEngineer) and click Create Application.
#
# Then add 2 lines to your `.env` file:
#
# PUSHOVER_USER=_put the key that's on the top right of your Pushover home screen and probably starts with a u_
# PUSHOVER_TOKEN=_put the key when you click into your new application called Agents (or whatever) and probably starts with an a_
#
# Remember to save your `.env` file, and run `load_dotenv(override=True)` after saving, to set your environment variables.
#
# Finally, click "Add Phone, Tablet or Desktop" to install on your phone.

# %%
load_dotenv(override=True)

# %%
pushover_user = os.getenv('PUSHOVER_USER')
pushover_token = os.getenv('PUSHOVER_TOKEN')
pushover_url = "https://api.pushover.net/1/messages.json"

# %%
if pushover_user:
    print(f"Pushover user found and starts with {pushover_user[0]}")
else:
    print("Pushover user not found")

if pushover_token:
    print(f"Pushover token found and starts with {pushover_token[0]}")
else:
    print("Pushover token not found")

# %%
def push(message):
    print(f"Push: {message}")
    payload = {"user": pushover_user, "token": pushover_token, "message": message}
    requests.post(pushover_url, data=payload)

# %%
push("MASSIVE DEAL!!")

# %%
from agents.messaging_agent import MessagingAgent

agent = MessagingAgent()
agent.push("SUCH A MASSIVE DEAL!!")

# %%
agent.notify("A special deal on Sumsung 60 inch LED TV going at a great bargain", 300, 1000, "www.samsung.com")
